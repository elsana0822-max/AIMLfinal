# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
df=pd.read_excel("skin_irritation.xlsx", sheet_name="Data_invivo")

# %%
df.head()
# Out:
#                     Record_ID Data_Type Formulation_ID  \
# 0   skin_irritation_invivo_18   In Vivo            NaN
# 1   skin_irritation_invivo_83   In Vivo            NaN
# 2   skin_irritation_invivo_80   In Vivo            NaN
# 3  skin_irritation_invivo_822   In Vivo          MIX82
# 4  skin_irritation_invivo_719   In Vivo         MIX380
#
#                Formulation_Name  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                     Captan 4L
# 4  Raid Roach & Ant Killer Plus
#
#                                        Chemical_Name CASRN DTXSID  \
# 0             Alcohol ethoxylate C12-15/E5 phosphate   NaN    NaN
# 1      C12-13 beta-branched primary alco hol sulfate   NaN    NaN
# 2  C12-13 beta-branched primary alco hol sulfate/...   NaN    NaN
# 3                         Captan-related derivatives   NaN    NaN
# 4                       Dichlorvos-related compounds   NaN    NaN
#
# ...

# %%
subset_df = df[(df['Mixture'] == 'Chemical')]
subset_df
# Out:
#                        Record_ID Data_Type Formulation_ID Formulation_Name  \
# 0      skin_irritation_invivo_18   In Vivo            NaN              NaN
# 1      skin_irritation_invivo_83   In Vivo            NaN              NaN
# 2      skin_irritation_invivo_80   In Vivo            NaN              NaN
# 5      skin_irritation_invivo_55   In Vivo            NaN              NaN
# 6      skin_irritation_invivo_48   In Vivo            NaN              NaN
# ...                          ...       ...            ...              ...
# 1969  skin_irritation_invivo_163   In Vivo            NaN              NaN
# 1970  skin_irritation_invivo_121   In Vivo            NaN              NaN
# 1971   skin_irritation_invivo_97   In Vivo            NaN              NaN
# 1972   skin_irritation_invivo_93   In Vivo            NaN              NaN
# 1981  skin_irritation_invivo_112   In Vivo            NaN              NaN
#
# ...

# %%
subset_df =df[df['Species'] == 'Human']

print(subset_df)
# Out:
#                       Record_ID Data_Type Formulation_ID Formulation_Name  \
# 0     skin_irritation_invivo_18   In Vivo            NaN              NaN
# 1     skin_irritation_invivo_83   In Vivo            NaN              NaN
# 2     skin_irritation_invivo_80   In Vivo            NaN              NaN
# 5     skin_irritation_invivo_55   In Vivo            NaN              NaN
# 6     skin_irritation_invivo_48   In Vivo            NaN              NaN
# ...                         ...       ...            ...              ...
# 1858  skin_irritation_invivo_76   In Vivo            NaN              NaN
# 1859   skin_irritation_invivo_8   In Vivo            NaN              NaN
# 1860   skin_irritation_invivo_8   In Vivo            NaN              NaN
# 1861  skin_irritation_invivo_39   In Vivo            NaN              NaN
# 1862  skin_irritation_invivo_39   In Vivo            NaN              NaN
#
#                                           Chemical_Name     CASRN  \
# ...

# %%
df['Mixture'].value_counts()
# Out:
# Mixture
# Mixture     1799
# Chemical     259
# Name: count, dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Species
# Rabbit    1878
# Human      180
# Name: count, dtype: int64

# %%
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------------------------------- ------ 6.8/8.1 MB 36.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 25.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 13.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 15.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 12.5 MB/s  0:00:00
# ...
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
# ...

# %%
df=pd.read_excel("skin_irritation.xlsx", sheet_name="Data_invivo")

# %%
subset_df=df[df['Endpoint']=='positive_reaction']

# %%
subset_df['Mixture'].hist(bins=10)

plt.title("Histogram of Positive Reactions")
plt.show()

# %%
df['Endpoint'].value_counts().plot(kind='bar')
plt.title("Count of Endpoints")
plt.show()

# %%
plt.figure(figsixe==(10,6))
plt.hist(positive_data['Response'], bins=20,
